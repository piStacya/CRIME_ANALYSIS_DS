# %% [markdown]
# Tabel, mille kohta väärtuste tabel käib.
#
# Unit: NR (konkreetne arv inimesi)

# %%
import pandas as pd
iccs = {
    "ICCS0101": "Intentional homicide",
    "ICCS02-04": "Serious violent crimes (aggregate)",
    "ICCS0401": "Robbery",
    "ICCS05012": "Burglary of residential premises",
    "ICCS050211": "Theft of a motorized land vehicle",
    "ICCS0601" : "Unlawful acts involving controlled drugs",
    "ICCS03011" : "Rape",
    "ICCS0301" : "Sexual violence",
    "ICCS03012" : "Sexual Assault",
    "TOTAL": "Total offences"
}

cities = {

}

df = pd.read_csv("..\\data\\cleanedDatasets\\crimes_recorded_by_the_police_by_offence_category_new.tsv", sep="\t")

df.iccs.value_counts()
# Out:
# iccs
# ICCS0101      39
# ICCS0401      39
# TOTAL         39
# ICCS0601      39
# ICCS02-04     38
# ICCS05012     38
# ICCS050211    37
# Name: count, dtype: int64

# %%
df2 = pd.read_csv(
    "..\\data\\cleanedDatasets\\intentional_homicide_and_sexual_offences_by_legal_status_and_sex_of_the_person_involved_new.tsv", sep="\t")

df2.iccs.value_counts()
# Out:
# iccs
# ICCS0101     931
# ICCS03011    887
# ICCS03012    869
# Name: count, dtype: int64

# %%
df3 = pd.read_csv(
    "..\\data\\cleanedDatasets\\legal_cases_processed_in_first_instance_courts_by_legal_status_of_the_court_process_since2022.tsv", sep="\t")
# Out:
# Index(['freq,leg_case,leg_stat,unit,geo\TIME_PERIOD', '2022 ', '2023 '], dtype='object')
