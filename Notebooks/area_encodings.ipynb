# %%
import pandas as pd
import numpy as np

nuts_df = pd.read_csv("../data/nutskoodikesed.csv", sep=";")
nuts_sr = pd.read_csv("../data/nutsSR.csv", sep=";")
nuts_latin = pd.read_csv("../data/nutscyrandgreek.csv", sep=";")

# %%
nuts_df = nuts_df[["Country code", "NUTS Code", "NUTS label", "NUTS level","Country order"]]
nuts_sr.columns
# Out:
# Index(['Country code', 'SR Code', 'SR label', 'SR level', 'Country order',
#        '#'],
#       dtype='object')

# %%
nuts_sr = nuts_sr[['Country code', 'SR Code', 'SR label', 'SR level', 'Country order']]
nuts_latin = nuts_latin[["Code", "Label", "Transliteration to Latin"]]
nuts_latin.head()
# Out:
#     Code                          Label         Transliteration to Latin
# 0    BG3  Северна и Югоизточна България  Severna i Yugoiztochna Bulgaria
# 1   BG31                  Северозападен                    Severozapaden
# 2  BG311                          Видин                            Vidin
# 3  BG312                        Монтана                          Montana
# 4  BG313                          Враца                           Vratsa

# %%
nuts_df.head()
# Out:
#   Country code NUTS Code                                         NUTS label  \
# 0           BE       BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 1           BE      BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 2           BE     BE100  Arr. de Bruxelles-Capitale/Arr. Brussel-Hoofdstad
# 3           BE       BE2                                      Vlaams Gewest
# 4           BE      BE21                                    Prov. Antwerpen
#
#    NUTS level  Country order
# 0         1.0            1.0
# 1         2.0            1.0
# 2         3.0            1.0
# 3         1.0            1.0
# 4         2.0            1.0

# %%
nuts_sr.head()
# Out:
#   Country code SR Code             SR label  SR level  Country order
# 0           IS     IS0               Ísland       1.0            1.0
# 1           IS    IS00               Ísland       2.0            1.0
# 2           IS   IS001     Höfuðborgarsvæði       3.0            1.0
# 3           IS   IS002           Landsbyggð       3.0            1.0
# 4           IS     ISZ  Extra-Regio level 1       1.0            1.0

# %%
data = pd.DataFrame({
    "Country code": pd.concat([nuts_df["Country code"], nuts_sr["Country code"]], axis=0),
    "NUTS Code": pd.concat([nuts_df["NUTS Code"], nuts_sr["SR Code"]], axis=0),
    "NUTS label": pd.concat([nuts_df["NUTS label"], nuts_sr["SR label"]], axis=0)
})
# Out:
#    Country code NUTS Code                                         NUTS label
# 0            BE       BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 1            BE      BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 2            BE     BE100  Arr. de Bruxelles-Capitale/Arr. Brussel-Hoofdstad
# 3            BE       BE2                                      Vlaams Gewest
# 4            BE      BE21                                    Prov. Antwerpen
# 5            BE     BE211                                     Arr. Antwerpen
# 6            BE     BE212                                      Arr. Mechelen
# 7            BE     BE213                                      Arr. Turnhout
# 8            BE      BE22                                 Prov. Limburg (BE)
# 9            BE     BE223                                      Arr. Tongeren
# 10           BE     BE224                                       Arr. Hasselt
# 11           BE     BE225                                       Arr. Maaseik
# 12           BE      BE23                              Prov. Oost-Vlaanderen
# 13           BE     BE231                                         Arr. Aalst
# 14           BE     BE232                                   Arr. Dendermonde
# 15           BE     BE233                                         Arr. Eeklo
# 16           BE     BE234                                          Arr. Gent
# 17           BE     BE235                                    Arr. Oudenaarde
# 18           BE     BE236                                  Arr. Sint-Niklaas
# 19           BE      BE24                               Prov. Vlaams-Brabant
# 20           BE     BE241                               Arr. Halle-Vilvoorde
# 21           BE     BE242                                        Arr. Leuven
# 22           BE      BE25                              Prov. West-Vlaanderen
# 23           BE     BE251                                        Arr. Brugge
# 24           BE     BE252                                     Arr. Diksmuide
# 25           BE     BE253                                         Arr. Ieper
# 26           BE     BE254                                      Arr. Kortrijk
# 27           BE     BE255                                      Arr. Oostende
# 28           BE     BE256                                     Arr. Roeselare
# 29           BE     BE257                                         Arr. Tielt
# 30           BE     BE258                                        Arr. Veurne
# 31           BE       BE3                                    Région wallonne
# 32           BE      BE31                               Prov. Brabant wallon
# 33           BE     BE310                                      Arr. Nivelles
# 34           BE      BE32                                      Prov. Hainaut
# 35           BE     BE323                                          Arr. Mons
# 36           BE     BE328                              Arr. Tournai-Mouscron
# 37           BE     BE329                                   Arr. La Louvière
# 38           BE     BE32A                                           Arr. Ath
# 39           BE     BE32B                                     Arr. Charleroi
# 40           BE     BE32C                                      Arr. Soignies
# 41           BE     BE32D                                         Arr. Thuin
# 42           BE      BE33                                        Prov. Liège
# 43           BE     BE331                                           Arr. Huy
# 44           BE     BE332                                         Arr. Liège
# 45           BE     BE334                                       Arr. Waremme
# 46           BE     BE335              Arr. Verviers — communes francophones
# 47           BE     BE336    Bezirk Verviers — Deutschsprachige Gemeinschaft
# 48           BE      BE34                              Prov. Luxembourg (BE)
# 49           BE     BE341                                         Arr. Arlon

# %%
data.to_csv("..\\data\\nutsAndSR.csv", sep="\t", index=False)

# %%
data.dropna(how="all")
data = data.sort_values("NUTS Code")
data = data.loc[data["Country code"]!="Country code", ["Country code","NUTS Code", "NUTS label"]]
data.to_csv("..\\data\\nutsAndSR.csv", sep="\t", index=False)

# %%
area_codes = {}
